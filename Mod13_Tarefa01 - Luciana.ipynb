# %% [markdown]
# # EBAC - Regressão II - regressão múltipla
#
# ## Tarefa I

# %% [markdown]
# #### Previsão de renda
#
# Vamos trabalhar com a base 'previsao_de_renda.csv', que é a base do seu próximo projeto. Vamos usar os recursos que vimos até aqui nesta base.
#
# |variavel|descrição|
# |-|-|
# |data_ref                | Data de referência de coleta das variáveis |
# |index                   | Código de identificação do cliente|
# |sexo                    | Sexo do cliente|
# |posse_de_veiculo        | Indica se o cliente possui veículo|
# |posse_de_imovel         | Indica se o cliente possui imóvel|
# |qtd_filhos              | Quantidade de filhos do cliente|
# |tipo_renda              | Tipo de renda do cliente|
# |educacao                | Grau de instrução do cliente|
# |estado_civil            | Estado civil do cliente|
# |tipo_residencia         | Tipo de residência do cliente (própria, alugada etc)|
# |idade                   | Idade do cliente|
# |tempo_emprego           | Tempo no emprego atual|
# |qt_pessoas_residencia   | Quantidade de pessoas que moram na residência|
# |renda                   | Renda em reais|

# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
import patsy

# %%
df = pd.read_csv('previsao_de_renda.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             15000 non-null  int64
#  1   data_ref               15000 non-null  object
#  2   id_cliente             15000 non-null  int64
#  3   sexo                   15000 non-null  object
#  4   posse_de_veiculo       15000 non-null  bool
#  5   posse_de_imovel        15000 non-null  bool
#  6   qtd_filhos             15000 non-null  int64
#  7   tipo_renda             15000 non-null  object
#  8   educacao               15000 non-null  object
#  9   estado_civil           15000 non-null  object
#  10  tipo_residencia        15000 non-null  object
#  11  idade                  15000 non-null  int64
#  12  tempo_emprego          12427 non-null  float64
#  13  qt_pessoas_residencia  15000 non-null  float64
# ...

# %%
df.tipo_renda.value_counts() # feito para todas para determinar o Treatment
# Out:
# tipo_renda
# Assalariado         7633
# Empresário          3508
# Pensionista         2582
# Servidor público    1268
# Bolsista               9
# Name: count, dtype: int64

# %% [markdown]
# 1. Ajuste um modelo para prever log(renda) considerando todas as covariáveis disponíveis.
#     - Utilizando os recursos do Patsy, coloque as variáveis qualitativas como *dummies*.
#     - Mantenha sempre a categoria mais frequente como casela de referência
#     - Avalie os parâmetros e veja se parecem fazer sentido prático.
#
#
# 2. Remova a variável menos significante e analise:
#     - Observe os indicadores que vimos, e avalie se o modelo melhorou ou piorou na sua opinião.
#     - Observe os parâmetros e veja se algum se alterou muito.
#
#
# 3. Siga removendo as variáveis menos significantes, sempre que o *p-value* for menor que 5%. Compare o modelo final com o inicial. Observe os indicadores e conclua se o modelo parece melhor.

# %%
y, x = patsy.dmatrices('np.log(renda) ~ C(sexo) + C(tipo_renda, Treatment(0)) + C(educacao, Treatment(2)) + C(estado_civil) + C(tipo_residencia, Treatment(1))', data=df)
x
# Out:
# DesignMatrix with shape (15000, 19)
#   Columns:
#     ['Intercept',
#      'C(sexo)[T.M]',
#      'C(tipo_renda, Treatment(0))[T.Bolsista]',
#      'C(tipo_renda, Treatment(0))[T.Empresário]',
#      'C(tipo_renda, Treatment(0))[T.Pensionista]',
#      'C(tipo_renda, Treatment(0))[T.Servidor público]',
#      'C(educacao, Treatment(2))[T.Primário]',
#      'C(educacao, Treatment(2))[T.Pós graduação]',
#      'C(educacao, Treatment(2))[T.Superior completo]',
#      'C(educacao, Treatment(2))[T.Superior incompleto]',
#      'C(estado_civil)[T.Separado]',
#      'C(estado_civil)[T.Solteiro]',
#      'C(estado_civil)[T.União]',
#      'C(estado_civil)[T.Viúvo]',
#      'C(tipo_residencia, Treatment(1))[T.Aluguel]',
#      'C(tipo_residencia, Treatment(1))[T.Com os pais]',
#      'C(tipo_residencia, Treatment(1))[T.Comunitário]',
#      'C(tipo_residencia, Treatment(1))[T.Estúdio]',
#      'C(tipo_residencia, Treatment(1))[T.Governamental]']
#   Terms:
#     'Intercept' (column 0)
# ...

# %%
sm.OLS(y,x).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:          np.log(renda)   R-squared:                       0.160
# Model:                            OLS   Adj. R-squared:                  0.159
# Method:                 Least Squares   F-statistic:                     158.0
# Date:                Thu, 04 Jan 2024   Prob (F-statistic):               0.00
# Time:                        22:11:36   Log-Likelihood:                -18121.
# No. Observations:               15000   AIC:                         3.628e+04
# Df Residuals:                   14981   BIC:                         3.642e+04
# Df Model:                          18
# Covariance Type:            nonrobust
# ...
#                                                         coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------------
# ...

# %%
y, x = patsy.dmatrices('np.log(renda) ~ C(sexo) + C(tipo_renda, Treatment(0)) + C(estado_civil) + C(tipo_residencia, Treatment(1))', data=df)
sm.OLS(y,x).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:          np.log(renda)   R-squared:                       0.156
# Model:                            OLS   Adj. R-squared:                  0.155
# Method:                 Least Squares   F-statistic:                     197.4
# Date:                Thu, 04 Jan 2024   Prob (F-statistic):               0.00
# Time:                        22:12:29   Log-Likelihood:                -18155.
# No. Observations:               15000   AIC:                         3.634e+04
# Df Residuals:                   14985   BIC:                         3.645e+04
# Df Model:                          14
# Covariance Type:            nonrobust
# ...
#                                                         coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------------
# ...

# %%
y, x = patsy.dmatrices('np.log(renda) ~ C(sexo) + C(tipo_renda, Treatment(0)) + C(tipo_residencia, Treatment(1))', data=df)
sm.OLS(y,x).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:          np.log(renda)   R-squared:                       0.155
# Model:                            OLS   Adj. R-squared:                  0.154
# Method:                 Least Squares   F-statistic:                     274.5
# Date:                Thu, 04 Jan 2024   Prob (F-statistic):               0.00
# Time:                        22:12:54   Log-Likelihood:                -18164.
# No. Observations:               15000   AIC:                         3.635e+04
# Df Residuals:                   14989   BIC:                         3.643e+04
# Df Model:                          10
# Covariance Type:            nonrobust
# ...
#                                                         coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------------
# ...

# %%
y, x = patsy.dmatrices('np.log(renda) ~ C(sexo) + C(tipo_renda, Treatment(0))', data=df)
sm.OLS(y,x).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:          np.log(renda)   R-squared:                       0.152
# Model:                            OLS   Adj. R-squared:                  0.152
# Method:                 Least Squares   F-statistic:                     539.2
# Date:                Thu, 04 Jan 2024   Prob (F-statistic):               0.00
# Time:                        22:14:32   Log-Likelihood:                -18184.
# No. Observations:               15000   AIC:                         3.638e+04
# Df Residuals:                   14994   BIC:                         3.643e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                                                       coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------
# ...

# %%
y, x = patsy.dmatrices('np.log(renda) ~ C(sexo)', data=df)
sm.OLS(y,x).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:          np.log(renda)   R-squared:                       0.141
# Model:                            OLS   Adj. R-squared:                  0.140
# Method:                 Least Squares   F-statistic:                     2452.
# Date:                Thu, 04 Jan 2024   Prob (F-statistic):               0.00
# Time:                        22:17:33   Log-Likelihood:                -18289.
# No. Observations:               15000   AIC:                         3.658e+04
# Df Residuals:                   14998   BIC:                         3.660e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %%
# o modelo inicial parece melhor, devido aos indicadores, que foram diminuindo conforme as variaveis foram sendo removidas.
