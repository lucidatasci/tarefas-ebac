# %% [markdown]
# # Modulo 21 exercício 2
#
# ### Demo - boarding_passes
#
# ![image.png](attachment:61ae4353-143b-4e01-a00e-c2c67932fabb.png)

# %% [markdown]
# ### Demo - aircrafts_data
#
# ![image.png](attachment:ae6fca9c-416b-4f5e-828d-71d4ad0f9297.png)

# %% [markdown]
# ### Demo - flights
#
# ![image.png](attachment:cb0979d8-ad81-4f0b-97b7-27c3d2027c6b.png)

# %% [markdown]
# ### Demo - airports_data
#
# ![image.png](attachment:0a524491-7362-4f44-8594-83c1e845c597.png)

# %% [markdown]
# ### Demo - bookings
#
# ![image.png](attachment:d35ee134-02fe-4887-9894-be45fe5e31c1.png)

# %% [markdown]
# ### Dvdrental - Category
#
# ![image.png](attachment:372b23e9-d444-4bb4-acff-9cf1e70d361d.png)

# %% [markdown]
# ### Dvdrental - city
#
# ![image.png](attachment:58b556ed-3298-4358-a93d-9f186edfbafa.png)

# %% [markdown]
# ### Dvdrental - country
#
# ![image.png](attachment:d3065201-6af5-492d-82a4-ce6d58e4e75f.png)

# %% [markdown]
# ### Dvdrental - customer
#
# ![image.png](attachment:9d8d72e1-3e36-4b3d-b25c-34178ba89fe7.png)

# %% [markdown]
# ### Dvdrental - film_actor
#
# ![image.png](attachment:35e42be5-4c5d-4e03-adfc-bb582c4d54e2.png)
